# %%
# Assigment 1
#sort and list dissending order
li = input('Enter values:').split()
# Out:
# Enter values:10,20,30,40,50

# %%
print(li)
# Out:
# ['10,20,30,40,50']

# %%
l2 = input('Enter values:').split
print(type(li))
# Out:
# Enter values:5,2,7,9,8,1
# <class 'list'>

# %%
l3 = [5,2,7,9,8,1]
print(l3)
# Out:
# [5, 2, 7, 9, 8, 1]

# %%
l3.sort()
print(l3)
# Out:
# [1, 2, 5, 7, 8, 9]

# %%
# Assigment 2
# Remove all occurence of an element from a list
li = [10,20,30,40,50,60]
print(li)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
li.remove(10)
print(li)
# Out:
# [20, 30, 40, 50, 60]

# %%
li.remove(20)
print(li)
# Out:
# [30, 40, 50, 60]

# %%
li.remove(30)
print(li)
# Out:
# [40, 50, 60]

# %%
li.remove(40)
print(li)
# Out:
# [50, 60]

# %%
li.remove(50)
print(li)
# Out:
# [60]

# %%
li.remove(60)
print(li)
# Out:
# []
